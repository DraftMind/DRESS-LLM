# %%
import pandas as pd
df = pd.read_csv('/data1/liyu25/ynliu/HumanizerRL/dataset/samples_sentences_mage_windows_250_350.csv')

# %%
result_dict = []
for idx, row in df.iterrows():
    result_dict.append({
        'question': row['text'],
    })
import json
with open('./mage.json', 'w') as f:
    json.dump(result_dict, f, indent=4)

# %%
df['len'] = df['text'].str.len()

# %%
df
# Out:
#                                                  text         topic category  \
# 0   Adversarial prompt engineering has become a cr...   AI Security    Paper
# 1   The proposed methodology leverages a multi-sta...   AI Security    Paper
# 2   Cross-model transferability tests reveal minim...   AI Security    Paper
# 3   This work underscores the necessity of robust ...   AI Security    Paper
# 4   Recent advancements in instruction tuning have...   AI Security    Paper
# 5   The 2023 “ChatGPT Plugin Injection Incident” [...   AI Security    Paper
# 6   3% success rate in GPT-3. 5 [3]), prompt leaki...   AI Security    Paper
# 7   Second, supervised safety tuning [7] induces c...   AI Security    Paper
# 8   Current solutions thus address symptoms rather...   AI Security    Paper
# 9   Recent research on adversarial attacks against...   AI Security    Paper
# 10  Multimodal adversarial attacks extend these te...   AI Security    Paper
# ...
