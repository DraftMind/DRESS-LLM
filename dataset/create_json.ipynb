# %%
import pandas as pd
df = pd.read_csv('~/share/RL/dataset/WritingTestBench.csv')

# %%
result_dict = []
for idx, row in df.iterrows():
    result_dict.append({
        'question': row['text'],
    })
import json
with open('./WritingTestBench.json', 'w') as f:
    json.dump(result_dict, f, indent=4)
